# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_sales = pd.read_csv('sales_train_validation.csv')
df_calendar = pd.read_csv('calendar.csv')
df_sell_prices = pd.read_csv('sell_prices.csv')

# %%
df_sales.shape
# Out:
# (30490, 1919)

# %%
df_sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# 0       1       3       0       1       1
# 1       1       0       0       0       0
# 2       1       0       1       1       1
# 3       0       1       3       7       2
# 4       1       2       2       2       4
#
# [5 rows x 1919 columns]

# %%
df_calendar.head(300)
# Out:
#            date  wm_yr_wk    weekday  wday  month  year      d  event_name_1  \
# 0    2011-01-29     11101   Saturday     1      1  2011    d_1           NaN
# 1    2011-01-30     11101     Sunday     2      1  2011    d_2           NaN
# 2    2011-01-31     11101     Monday     3      1  2011    d_3           NaN
# 3    2011-02-01     11101    Tuesday     4      2  2011    d_4           NaN
# 4    2011-02-02     11101  Wednesday     5      2  2011    d_5           NaN
# ..          ...       ...        ...   ...    ...   ...    ...           ...
# 295  2011-11-20     11143     Sunday     2     11  2011  d_296           NaN
# 296  2011-11-21     11143     Monday     3     11  2011  d_297           NaN
# 297  2011-11-22     11143    Tuesday     4     11  2011  d_298           NaN
# 298  2011-11-23     11143  Wednesday     5     11  2011  d_299           NaN
# 299  2011-11-24     11143   Thursday     6     11  2011  d_300  Thanksgiving
#
#     event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0            NaN          NaN          NaN        0        0        0
# 1            NaN          NaN          NaN        0        0        0
# 2            NaN          NaN          NaN        0        0        0
# 3            NaN          NaN          NaN        1        1        0
# 4            NaN          NaN          NaN        1        0        1
# ..           ...          ...          ...      ...      ...      ...
# 295          NaN          NaN          NaN        0        0        0
# 296          NaN          NaN          NaN        0        0        0
# 297          NaN          NaN          NaN        0        0        0
# 298          NaN          NaN          NaN        0        0        0
# 299     National          NaN          NaN        0        0        0
#
# [300 rows x 14 columns]

# %%
df_sell_prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
df_sell_prices.shape
# Out:
# (6841121, 4)

# %%
plt.figure()
plt.plot(list(range(1913)),df_sales.iloc[11][6:])
plt.show()

# %%
df_sales.iloc[0][6:]
# Out:
# d_1       0
# d_2       0
# d_3       0
# d_4       0
# d_5       0
#          ..
# d_1909    1
# d_1910    3
# d_1911    0
# d_1912    1
# d_1913    1
# Name: 0, Length: 1913, dtype: object

# %%
list(range(1914))[-1]
# Out:
# 1913
